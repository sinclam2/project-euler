# %% [markdown]
# # The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be: 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...

# %% [markdown]
# # Let us list the factors of the first seven triangle numbers:
#
# ## 1: 1
# ## 3: 1,3
# ## 6: 1,2,3,6
# ## 10: 1,2,5,10
# ## 15: 1,3,5,15
# ## 21: 1,3,7,21
# ## 28: 1,2,4,7,14,28

# %% [markdown]
# # We can see that 28 is the first triangle number to have over five divisors.
#
# # What is the value of the first triangle number to have over five hundred divisors?

# %% [markdown]
# ______

# %%
import numpy as np

# %% [markdown]
# **Creating a list of the first 50000 triangle numbers**

# %%
list_50000 = list(np.cumsum(range(1,50000)))

# %%
def count_factors(x):
    list_candidates = list(range(1, x//2+1))
    count = 1
    for i in list_candidates:
        if x%i==0:
            count += 1
    return count

# %%
def find_first(n):
    for x in list_5000:
        if count_factors(x)>n:
            return x

# %%
num = find_first(500)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-16319516a8a8> in <module>()
# ----> 1 num = find_first(500)
#
# <ipython-input-36-5121649041b1> in find_first(n)
#       1 def find_first(n):
#       2     for x in list_5000:
# ----> 3         if count_factors(x)>n:
#       4             return x
#
# <ipython-input-35-56aa6cbfa558> in count_factors(x)
#       1 def count_factors(x):
#       2     list_candidates = list(range(1, x//2+1))
# ----> 3     list_factors = [i for i in list_candidates if x%i==0]
#       4     list_factors.append(x)
#       5     return len(list_factors)
#
# KeyboardInterrupt:

# %%
list_50000[-1]
# Out:
# 1249975000

# %%
count_factors(1249975000)
