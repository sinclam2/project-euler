# %% [markdown]
# # Triangle, square, pentagonal, hexagonal, heptagonal, and octagonal numbers are all figurate (polygonal) numbers and are generated by the following formulae:
#
# ![](images/61.PNG)

# %% [markdown]
# # The ordered set of three 4-digit numbers: 8128, 2882, 8281, has three interesting properties.
#
# 1. The set is cyclic, in that the last two digits of each number is the first two digits of the next number (including the last number with the first).
# 2. Each polygonal type: triangle ($P_{3,127}=8128$), square ($P_{4,91}=8281$), and pentagonal ($P_{5,44}=2882$), is represented by a different number in the set.
# 3. This is the only set of 4-digit numbers with this property.

# %% [markdown]
# # Find the sum of the only ordered set of six cyclic 4-digit numbers for which each polygonal type: triangle, square, pentagonal, hexagonal, heptagonal, and octagonal, is represented by a different number in the set.

# %% [markdown]
# ____

# %%
def triangle(n):
    return n*(n+1)/2.0

# %%
def square(n):
    return n**2

# %%
def pentagonal(n):
    return n*(3*n-1)/2.0

# %%
def hexagonal(n):
    return n*(2*n-1)

# %%
def heptagonal(n):
    return n*(5*n-3)/2.0

# %%
def octagonal(n):
    return n*(3*n-2)

# %% [markdown]
# ### Creating a list of all 4 digit numbers that are of each type

# %%
list_t = []
list_s = []
list_p = []
list_hx = []
list_hp = []
list_o = []

for n in range(1,1000):
    t = triangle(n)
    if 1<=t//1000<10:
        list_t.append(t)
    
    s = square(n)
    if 1<=s//1000<10:
        list_s.append(s)
    
    p = pentagonal(n)
    if 1<=p//1000<10:
        list_p.append(p)
    
    hx = hexagonal(n)
    if 1<=hx//1000<10:
        list_hx.append(hx)
    
    hp = heptagonal(n)
    if 1<=hp//1000<10:
        list_hp.append(hp)
    
    o = octagonal(n)
    if 1<=o//1000<10:
        list_o.append(o)

# %%
#wlog, we'll take val_1 from list_t
def check(val_1):
    
    list_of_lists1 = [list_s,list_p,list_hx,list_hp,list_o]
    
    first_two_digits1 = val_1 - (val_1//100)*100
    
    for list_2 in list_of_lists1:
        
        list_candidates2 = [x for x in list_2 if x//100==first_two_digits1]
        
        list_of_lists2 = list_of_lists1.copy()
        list_of_lists2.remove(list_2)
        
        for val_2 in list_candidates2:
            first_two_digits2 = val_2 - (val_2//100)*100
            
            for list_3 in list_of_lists2:
        
                list_candidates3 = [x for x in list_3 if x//100==first_two_digits2]

                list_of_lists3 = list_of_lists2.copy()
                list_of_lists3.remove(list_3)

                for val_3 in list_candidates3:
                    first_two_digits3 = val_3 - (val_3//100)*100
                    
                    for list_4 in list_of_lists3:

                        list_candidates4 = [x for x in list_4 if x//100==first_two_digits3]

                        list_of_lists4 = list_of_lists3.copy()
                        list_of_lists4.remove(list_4)

                        for val_4 in list_candidates4:
                            first_two_digits4 = val_4 - (val_4//100)*100
                            
                            for list_5 in list_of_lists4:

                                list_candidates5 = [x for x in list_5 if x//100==first_two_digits4]

                                list_of_lists5 = list_of_lists4.copy()
                                list_of_lists5.remove(list_5)
                                
                                for val_5 in list_candidates5:
                                    first_two_digits5 = val_5 - (val_5//100)*100
                                    
                                    for final_list in list_of_lists5:
                                        
                                        list_candidates6 = [x for x in final_list if x//100==first_two_digits5]
                                        
                                        for final_val in list_candidates6:
                                            
                                            if final_val - (final_val//100)*100 == val_1//100:
                                                return val_1, val_2, val_3, val_4, val_5, final_val
    return False

# %%
for val_1 in list_t:
    result = check(val_1)
    if result==False:
        pass
    else:
        print(result, sum(result))
        found = True
# Out:
# (8256.0, 5625, 2512.0, 1281, 8128, 2882.0) 28684.0

# %% [markdown]
# # Answer: 28684
