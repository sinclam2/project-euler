# %% [markdown]
# # A perfect number is a number for which the sum of its proper divisors is exactly equal to the number. For example, the sum of the proper divisors of 28 would be 1 + 2 + 4 + 7 + 14 = 28, which means that 28 is a perfect number.
#
# # A number n is called deficient if the sum of its proper divisors is less than n and it is called abundant if this sum exceeds n.
#
# # As 12 is the smallest abundant number, 1 + 2 + 3 + 4 + 6 = 16, the smallest number that can be written as the sum of two abundant numbers is 24. By mathematical analysis, it can be shown that all integers greater than 28123 can be written as the sum of two abundant numbers. However, this upper limit cannot be reduced any further by analysis even though it is known that the greatest number that cannot be expressed as the sum of two abundant numbers is less than this limit.
#
# # Find the sum of all the positive integers which cannot be written as the sum of two abundant numbers.

# %% [markdown]
# ____

# %%
import numpy as np

# %%
def get_factors(n):
    array = np.arange(1,n//2+1)
    divisors = n/array
    return np.sum(array*((divisors//1)==divisors)*1)

# %% [markdown]
# - If a number is an abundant number, then we know that its multiple by 2 is also an abundant number
#     - Why?
#
# - Let $f(n)$ be the sum of the proper factors of $n$
#     - Then, the list of proper factors of $2n$ is the same as the list for $n$, except with $n$ added to the end
#         - This means that $f(2n) = f(n) + n < n+n=2n \implies 2n$ is also an abundant number

# %%
list_abundant = []

list_to_check = np.arange(12, 28124)

while len(list_to_check)>0:
    check = list_to_check[0]
    list_to_check = list_to_check[1:]
    if get_factors(check)> check:
        list_abundant.append(check)
        list_to_check = list_to_check[(list_to_check/check)%2!=0]

# %%
list_abundant
# Out:
# [12,
#  18,
#  20,
#  30,
#  42,
#  54,
#  56,
#  66,
#  70,
#  78,
#  88,
#  90,
#  100,
#  102,
#  104,
#  114,
#  126,
#  138,
#  150,
#  162,
#  174,
#  186,
#  196,
#  198,
#  210,
#  220,
#  222,
#  234,
#  246,
#  258,
#  260,
#  270,
#  272,
#  282,
#  294,
#  304,
#  306,
#  308,
#  318,
#  330,
#  340,
#  342,
#  350,
#  354,
#  364,
#  366,
#  368,
#  378,
#  380,
#  390,
#  402,
#  414,
#  426,
#  438,
#  450,
#  460,
#  462,
#  464,
#  474,
#  476,
#  486,
#  490,
#  498,
#  500,
#  510,
#  522,
#  532,
#  534,
#  546,
#  550,
#  558,
#  570,
#  572,
#  580,
#  582,
#  594,
#  606,
#  618,
#  620,
#  630,
#  642,
#  644,
#  650,
#  654,
#  666,
#  678,
#  690,
#  702,
#  714,
#  726,
#  738,
#  740,
#  748,
#  750,
#  762,
#  770,
#  774,
#  786,
#  798,
#  810,
#  812,
#  820,
#  822,
#  834,
#  836,
#  846,
#  858,
#  860,
#  868,
#  870,
#  882,
#  894,
#  906,
#  910,
#  918,
#  930,
#  940,
#  942,
#  945,
#  954,
#  966,
#  968,
#  978,
#  990,
#  992,
#  1002,
# ...

# %%
start_time = time.time()
list_to_check = list(range(12, 28124))
list_to_check = [x for x in list_to_check[1:] if (x/check)%2!=0]
end_time = time.time()
print(end_time-start_time)
# Out:
# 0.005997896194458008

# %%
start_time = time.time()
list_to_check = np.arange(12, 28124)
check = 12
list_to_check = (list_to_check[1:])[(list_to_check[1:]/check%2)!=0]
end_time = time.time()
print(end_time-start_time)
# Out:
# 0.0030019283294677734

# %%
list_to_check
# Out:
# array([   12,    13,    14, ..., 28121, 28122, 28123])
