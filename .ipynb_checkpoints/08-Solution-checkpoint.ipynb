# %% [markdown]
# # The four adjacent digits in the 1000-digit number that have the greatest product are 9 × 9 × 8 × 9 = 5832.

# %% [markdown]
# ### ...

# %% [markdown]
# # Find the thirteen adjacent digits in the 1000-digit number that have the greatest product. What is the value of this product?

# %%
num = ...

# %%
window = 13

# %%
max_product = 0
for i in range(1000-window):
    str_num_chopped = str(num)[i:window+i]
    list_num_chopped = [int(x) for x in str_num_chopped]
    product = 1
    for x in list_num_chopped:
        product*=x
    #product = np.prod(list_num_chopped)
    if product > max_product:
        max_product = product
        print(max_product)
# Out:
# 5000940
# 9797760
# 13063680
# 25401600
# 50803200
# 71124480
# 284497920
# 568995840
# 1020366720
# 1632586752
# 2040733440
# 2972712960
# 6270566400
# 14108774400
# 23514624000

# %% [markdown]
# ## Answer: 23,514,624,000
